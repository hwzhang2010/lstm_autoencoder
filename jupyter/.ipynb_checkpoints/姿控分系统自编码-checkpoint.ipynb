# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from math import sqrt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
tf.__version__, tf.keras.__version__
# Out:
# ('2.3.0', '2.4.0')

# %%
# 时间格式转化
def parser(x):
    #return pd.to_datetime(x, format='%m/%d/%Y %H:%M:%S')
    return pd.to_datetime(x, format='%Y-%m-%d %H:%M:%S')

# %%
# 将数据转换为监督学习型数据，删掉NaN值
def timeseries_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    # 获取特征值数量n_vars
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    #print(df)
    
    cols, names = list(), list()
    
    # input sequence(t-n, ... , t-1)
    # 创建n个v(t-1)作为列名
    for i in range(n_in, 0, -1):
        # 向列表cols中添加1个df.shift(1)的数据
        cols.append(df.shift(i))
        #print(cols)
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        
    # output sequence (t, t+1, ... , t+n)
    for i in range(0, n_out):
        # 向列表cols中添加1个df.shift(-1)的数据
        cols.append(df.shift(-i))
        #print(cols)
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    #print(cols)
    
    # 将列表中的两个张量按照列拼接起来，list(v1, v2) -> [v1, v2], 其中v1向下移动了1行，此时v1, v2是监督学习型数据
    agg = pd.concat(cols, axis=1)
    #print(agg)
    
    # 重定义列名
    agg.columns = names
    #print(agg)
    
    # 删除空值
    if dropnan:
        agg.dropna(inplace = True)
        
    return agg

# %%
# 将数据缩放到[-1,1]之间的数
def scale(dataset):
    # 创建1个缩放器
    scaler = MinMaxScaler(feature_range=(-1,1))
    scaler = scaler.fit(dataset)
    #print(dataset)
    
    # 缩放
    dataset_scaled = scaler.transform(dataset)
    #print(dataset_scaled)
    
    return scaler, dataset_scaled

# %%
# 逆缩放
def invert_scale(scaler, yhat, y):
    # 逆缩放输入形状为(n,2), 输出形状为(n,2)
    inverted_yhat = scaler.inverse_transform(yhat)
    inverted_y = scaler.inverse_transform(y)
    
    return inverted_yhat, inverted_y

# %%
# 数据拆分：拆分为训练集，测试集
def split_dataset(dataset, seq_len = 100):
    # 数据集长度
    length = len(dataset)
    
    # 初始训练集索引为空列表
    index_train = []
    # 初始测试集索引为空列表
    index_test = []
    
    for i in range(length):
        if (i % seq_len < seq_len - 30):
            index_train.append(i)
        else:
            index_test.append(i)
    
    
    
    # 前70%个作为训练集
    #train = [dataset[index] for index in index_train]
    train = np.array(dataset)[index_train]
    # 后30%个作为测试集
    #test = [dataset[index] for index in index_test]
    test = np.array(dataset)[index_test]
        
    return train, test

# %%
# 构建1个LSTM网络模型，并进行训练
def fit_lstm(train_X, train_y, test_X, test_y, batch_size, nb_epochs, neurons):
    model = tf.keras.Sequential()
    # neurons是神经元个数，batch_size是样本个数，batch_input_shape是输入形状
    # stateful是状态保留
    # 1.同一批数据反复训练很多次，可保留每次训练状态供下次使用
    # 2.不同批数据之间有顺序关联，可保留每次训练状态
    # 3.不同批次数据，数据之间没有关联
    # 定义编码器
    model.add(tf.keras.layers.LSTM(neurons, input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True))
    model.add(tf.keras.layers.LSTM(8))
    # 重复编码
    model.add(tf.keras.layers.RepeatVector(14))
    # 解码器
    model.add(tf.keras.layers.LSTM(8, return_sequences=True))
    model.add(tf.keras.layers.LSTM(16, return_sequences=True))
    # 定义输出模型--全连接层
    model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(14)))
    model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(1)))
    
    # 定义损失函数和优化器
    model.compile(loss='mean_squared_error', optimizer='adam')
    
    # 拟合网络
    history = model.fit(train_X, train_y, epochs=nb_epochs, batch_size=batch_size, validation_data=(test_X, test_y), verbose=2, shuffle=False)
        
    return model, history

# %%
# 加载数据
df = pd.read_csv('./dataset/姿控分系统遥测.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
raw_values = df.values
#df.tail(), raw_values

# %%
x1, x2 = split_dataset(raw_values, seq_len=100)
x1.shape, x2.shape
# Out:
# ((5722, 14), (2430, 14))

# %%
# 将所有数据缩放到[-1, 1]之间
scaler, scaled_values = scale(x1)
scaled_values, scaled_values.shape
# Out:
# (array([[ 0.9760707 ,  0.16984324, -0.10522083, ...,  0.22157406,
#           0.12362335,  0.63751081],
#         [ 0.9760707 ,  0.16984324, -0.10522083, ...,  0.22157406,
#           0.12362335,  0.63751081],
#         [ 0.9760707 ,  0.16984324, -0.10522083, ...,  0.22157406,
#           0.12362335,  0.63751081],
#         ...,
#         [ 0.99067314,  0.15455586, -0.16571772, ...,  0.22162308,
#           0.12362335,  0.63761258],
#         [ 0.99067314,  0.15455586, -0.16571772, ...,  0.22162308,
#           0.12362335,  0.63761258],
#         [ 0.99067314,  0.15455586, -0.16571772, ...,  0.22162308,
#           0.12362335,  0.63761258]]),
#  (5722, 14))

# %%
# 将数据转换为监督学习型数据
supervised = timeseries_to_supervised(scaled_values, 4, 1)
supervised_values = supervised.values
supervised_values, supervised_values.shape
# Out:
# (array([[ 0.9760707 ,  0.16984324, -0.10522083, ...,  0.22157406,
#           0.12362335,  0.63751081],
#         [ 0.9760707 ,  0.16984324, -0.10522083, ...,  0.22157406,
#           0.12362335,  0.63751081],
#         [ 0.9760707 ,  0.16984324, -0.10522083, ...,  0.22157406,
#           0.12362335,  0.63751081],
#         ...,
#         [ 0.9896937 ,  0.15575019, -0.16061376, ...,  0.22162308,
#           0.12362335,  0.63761258],
#         [ 0.99067314,  0.15455586, -0.16571772, ...,  0.22162308,
#           0.12362335,  0.63761258],
#         [ 0.99067314,  0.15455586, -0.16573916, ...,  0.22162308,
#           0.12362335,  0.63761258]]),
#  (5718, 70))

# %%
# 定义特征个数(用变量表示特征，标签)
n_features = 14

# %%
# 将数据拆分为训练集，测试集
train, test = split_dataset(supervised_values, seq_len=100)
train_X, train_y = train[:, :4*n_features], train[:, 4*n_features:]
test_X, test_y = test[:, :4*n_features], test[:, 4*n_features:]
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((4008, 56), (4008, 14), (1710, 56), (1710, 14))

# %%
# 将输入数据转换成3维张量[samples, timesteps, features], [1次批量n条数据， 每条数据1个步长，14个特征值]
train_X = train_X.reshape((train_X.shape[0], 4, n_features))
test_X = test_X.reshape((test_X.shape[0], 4, n_features))
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((4008, 4, 14), (4008, 14), (1710, 4, 14), (1710, 14))

# %%
# 构建1个LSTM网络模型，进行训练，样本数：4，循环训练次数：500， LSTM层神经元个数：16,8,16
lstm_model, history = fit_lstm(train_X, train_y, test_X, test_y, 4, 500, 16)
# Out:
# Epoch 1/500
# 1002/1002 - 9s - loss: 0.2897 - val_loss: 0.3222
# Epoch 2/500
# 1002/1002 - 8s - loss: 0.2812 - val_loss: 0.3555
# Epoch 3/500
# 1002/1002 - 7s - loss: 0.2788 - val_loss: 0.3106
# Epoch 4/500
# 1002/1002 - 7s - loss: 0.2604 - val_loss: 0.3395
# Epoch 5/500
# 1002/1002 - 7s - loss: 0.1669 - val_loss: 0.1911
# Epoch 6/500
# 1002/1002 - 8s - loss: 0.0915 - val_loss: 0.2107
# Epoch 7/500
# 1002/1002 - 7s - loss: 0.0799 - val_loss: 0.1824
# Epoch 8/500
# 1002/1002 - 7s - loss: 0.0721 - val_loss: 0.1799
# Epoch 9/500
# 1002/1002 - 7s - loss: 0.0645 - val_loss: 0.1654
# Epoch 10/500
# 1002/1002 - 7s - loss: 0.0590 - val_loss: 0.1732
# Epoch 11/500
# 1002/1002 - 7s - loss: 0.0589 - val_loss: 0.1804
# Epoch 12/500
# 1002/1002 - 7s - loss: 0.0634 - val_loss: 0.1770
# Epoch 13/500
# 1002/1002 - 7s - loss: 0.0602 - val_loss: 0.1515
# Epoch 14/500
# 1002/1002 - 7s - loss: 0.0557 - val_loss: 0.1767
# Epoch 15/500
# 1002/1002 - 7s - loss: 0.0549 - val_loss: 0.1556
# Epoch 16/500
# 1002/1002 - 7s - loss: 0.0520 - val_loss: 0.1565
# Epoch 17/500
# 1002/1002 - 7s - loss: 0.0555 - val_loss: 0.1703
# Epoch 18/500
# 1002/1002 - 7s - loss: 0.0473 - val_loss: 0.1621
# Epoch 19/500
# 1002/1002 - 7s - loss: 0.0431 - val_loss: 0.1548
# Epoch 20/500
# 1002/1002 - 7s - loss: 0.0400 - val_loss: 0.1667
# Epoch 21/500
# 1002/1002 - 7s - loss: 0.0346 - val_loss: 0.1516
# Epoch 22/500
# 1002/1002 - 7s - loss: 0.0325 - val_loss: 0.1549
# Epoch 23/500
# 1002/1002 - 7s - loss: 0.0317 - val_loss: 0.1488
# Epoch 24/500
# 1002/1002 - 7s - loss: 0.0301 - val_loss: 0.1518
# Epoch 25/500
# 1002/1002 - 7s - loss: 0.0282 - val_loss: 0.1543
# Epoch 26/500
# 1002/1002 - 7s - loss: 0.0306 - val_loss: 0.1814
# Epoch 27/500
# 1002/1002 - 7s - loss: 0.0290 - val_loss: 0.1525
# Epoch 28/500
# 1002/1002 - 7s - loss: 0.0256 - val_loss: 0.1507
# 1002/1002 - 7s - loss: 0.0024 - val_loss: 0.0062
# Epoch 479/500
# 1002/1002 - 7s - loss: 0.0021 - val_loss: 0.0055
# Epoch 480/500
# 1002/1002 - 7s - loss: 0.0022 - val_loss: 0.0055
# Epoch 481/500
# 1002/1002 - 7s - loss: 0.0021 - val_loss: 0.0056
# Epoch 482/500
# 1002/1002 - 7s - loss: 0.0020 - val_loss: 0.0061
# Epoch 483/500
# 1002/1002 - 7s - loss: 0.0022 - val_loss: 0.0080
# Epoch 484/500
# 1002/1002 - 7s - loss: 0.0026 - val_loss: 0.0066
# Epoch 485/500
# 1002/1002 - 7s - loss: 0.0022 - val_loss: 0.0062
# Epoch 486/500
# 1002/1002 - 7s - loss: 0.0020 - val_loss: 0.0055
# Epoch 487/500
# 1002/1002 - 7s - loss: 0.0022 - val_loss: 0.0058
# Epoch 488/500
# 1002/1002 - 7s - loss: 0.0023 - val_loss: 0.0056
# Epoch 489/500
# 1002/1002 - 7s - loss: 0.0023 - val_loss: 0.0057
# Epoch 490/500
# 1002/1002 - 7s - loss: 0.0022 - val_loss: 0.0064
# Epoch 491/500
# 1002/1002 - 7s - loss: 0.0023 - val_loss: 0.0063
# Epoch 492/500
# 1002/1002 - 7s - loss: 0.0022 - val_loss: 0.0061
# Epoch 493/500
# 1002/1002 - 7s - loss: 0.0024 - val_loss: 0.0071
# Epoch 494/500
# 1002/1002 - 7s - loss: 0.0022 - val_loss: 0.0063
# Epoch 495/500
# 1002/1002 - 7s - loss: 0.0022 - val_loss: 0.0077
# Epoch 496/500
# 1002/1002 - 7s - loss: 0.0022 - val_loss: 0.0056
# Epoch 497/500
# 1002/1002 - 7s - loss: 0.0023 - val_loss: 0.0063
# Epoch 498/500
# 1002/1002 - 7s - loss: 0.0025 - val_loss: 0.0059
# Epoch 499/500
# 1002/1002 - 7s - loss: 0.0022 - val_loss: 0.0055
# Epoch 500/500
# 1002/1002 - 7s - loss: 0.0020 - val_loss: 0.0054

# %%
# 训练损失
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
lstm_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 4, 16)             1984
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 8)                 800
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 14, 8)             0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 14, 8)             544
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 14, 16)            1600
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 14, 14)            238
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 14, 1)             15
# =================================================================
# Total params: 5,181
# Trainable params: 5,181
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 使用拟合后的网络进行预测
yhat = lstm_model.predict(test_X, batch_size=4)
yhat = yhat.reshape(yhat.shape[0], yhat.shape[1])
yhat, test_X, test_y
# Out:
# (array([[ 0.9571043 ,  0.1580529 , -0.12567522, ...,  0.19620575,
#           0.11079477,  0.61308676],
#         [ 0.9571091 ,  0.15805174, -0.12567097, ...,  0.19621165,
#           0.11079834,  0.61308974],
#         [ 0.9570967 ,  0.15805466, -0.12568292, ...,  0.19619618,
#           0.11078961,  0.61308163],
#         ...,
#         [ 0.9904684 ,  0.15599285, -0.15757939, ...,  0.22858126,
#           0.12056737,  0.6503026 ],
#         [ 0.9904684 ,  0.15599354, -0.15757933, ...,  0.22858192,
#           0.12056641,  0.65030354],
#         [ 0.9904692 ,  0.1559949 , -0.15757823, ...,  0.22858305,
#           0.12056531,  0.6503037 ]], dtype=float32),
#  array([[[ 0.9760707 ,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081]],
#
#         [[ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.9760707 ,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081]],
#
#         [[ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.9760707 ,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081]],
#
#         ...,
#
#         [[ 0.98942659,  0.15606867, -0.15928416, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.15606867, -0.15926271, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.15604877, -0.15928416, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.15604877, -0.15926271, ...,  0.22159857,
#            0.12334802,  0.63761258]],
#
#         [[ 0.98942659,  0.15606867, -0.15926271, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.15604877, -0.15928416, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.15604877, -0.15926271, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.15606867, -0.15926271, ...,  0.22159857,
#            0.12334802,  0.63761258]],
#
#         [[ 0.98942659,  0.15604877, -0.15928416, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.15604877, -0.15926271, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.15606867, -0.15926271, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98944885,  0.15606867, -0.15928416, ...,  0.22159857,
#            0.12334802,  0.63761258]]]),
#  array([[ 0.9760707 ,  0.169684  , -0.1053495 , ...,  0.22157406,
#           0.12362335,  0.63751081],
#         [ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#           0.12362335,  0.63751081],
#         [ 0.9760707 ,  0.169684  , -0.1053495 , ...,  0.22157406,
#           0.12362335,  0.63751081],
#         ...,
#         [ 0.98942659,  0.15606867, -0.15926271, ...,  0.22159857,
#           0.12334802,  0.63761258],
#         [ 0.98944885,  0.15606867, -0.15928416, ...,  0.22159857,
#           0.12334802,  0.63761258],
#         [ 0.98942659,  0.15604877, -0.15928416, ...,  0.22159857,
#           0.12334802,  0.63761258]]))

# %%
# 对替换后的inv_yhat预测数据进行逆缩放
inv_yhat = scaler.inverse_transform(yhat)
inv_yhat, inv_yhat.shape
# Out:
# (array([[ 9.6360952e-01, -1.2688318e-01,  1.7603201e-01, ...,
#          -5.1700082e-02, -2.4296702e-03, -1.2000147e-02],
#         [ 9.6361166e-01, -1.2688376e-01,  1.7603400e-01, ...,
#          -5.1688045e-02, -2.4290208e-03, -1.1998683e-02],
#         [ 9.6360606e-01, -1.2688230e-01,  1.7602843e-01, ...,
#          -5.1719595e-02, -2.4306066e-03, -1.2002666e-02],
#         ...,
#         [ 9.7859800e-01, -1.2791809e-01,  1.6115494e-01, ...,
#           1.4344350e-02, -6.5496628e-04,  6.2849196e-03],
#         [ 9.7859800e-01, -1.2791775e-01,  1.6115497e-01, ...,
#           1.4345689e-02, -6.5513945e-04,  6.2853880e-03],
#         [ 9.7859842e-01, -1.2791707e-01,  1.6115549e-01, ...,
#           1.4347998e-02, -6.5533968e-04,  6.2854760e-03]], dtype=float32),
#  (1710, 14))

# %%
# 对重构后数据进行逆缩放
inv_y = scaler.inverse_transform(test_y)
inv_y, inv_y.shape
# Out:
# (array([[ 9.7213e-01, -1.2104e-01,  1.8551e-01, ...,  5.0000e-05,
#          -1.0000e-04,  0.0000e+00],
#         [ 9.7214e-01, -1.2104e-01,  1.8551e-01, ...,  5.0000e-05,
#          -1.0000e-04,  0.0000e+00],
#         [ 9.7213e-01, -1.2104e-01,  1.8551e-01, ...,  5.0000e-05,
#          -1.0000e-04,  0.0000e+00],
#         ...,
#         [ 9.7813e-01, -1.2788e-01,  1.6037e-01, ...,  1.0000e-04,
#          -1.5000e-04,  5.0000e-05],
#         [ 9.7814e-01, -1.2788e-01,  1.6036e-01, ...,  1.0000e-04,
#          -1.5000e-04,  5.0000e-05],
#         [ 9.7813e-01, -1.2789e-01,  1.6036e-01, ...,  1.0000e-04,
#          -1.5000e-04,  5.0000e-05]]),
#  (1710, 14))

# %%
# 计算预测列和真实列的误差RMSE值
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print("Test RMSE: %.3f" % rmse)

# 真实值和预测值之间的平均绝对误差
mae = mean_absolute_error(inv_y, inv_yhat)
print("Test MAE: %.3f" % mae)
# Out:
# Test RMSE: 0.597
# Test MAE: 0.155

# %%
# 作图显示
plt.plot(inv_y[:, 3])
plt.plot(inv_yhat[:, 3])
plt.show()

# %%
# save model to single file
lstm_model.save('./models/lstm_model_adcs.h5')

# %%
# load model from single file
load_model = tf.keras.models.load_model('./models/lstm_model_adcs.h5')

# %%
load_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 4, 16)             1984
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 8)                 800
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 14, 8)             0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 14, 8)             544
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 14, 16)            1600
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 14, 14)            238
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 14, 1)             15
# =================================================================
# Total params: 5,181
# Trainable params: 5,181
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 使用拟合后的网络进行预测
yhat = load_model.predict(test_X, batch_size=4)
yhat = yhat.reshape(yhat.shape[0], yhat.shape[1])
yhat, test_X, test_y
# Out:
# (array([[ 0.9571043 ,  0.1580529 , -0.12567522, ...,  0.19620575,
#           0.11079477,  0.61308676],
#         [ 0.9571091 ,  0.15805174, -0.12567097, ...,  0.19621165,
#           0.11079834,  0.61308974],
#         [ 0.9570967 ,  0.15805466, -0.12568292, ...,  0.19619618,
#           0.11078961,  0.61308163],
#         ...,
#         [ 0.9904684 ,  0.15599285, -0.15757939, ...,  0.22858126,
#           0.12056737,  0.6503026 ],
#         [ 0.9904684 ,  0.15599354, -0.15757933, ...,  0.22858192,
#           0.12056641,  0.65030354],
#         [ 0.9904692 ,  0.1559949 , -0.15757823, ...,  0.22858305,
#           0.12056531,  0.6503037 ]], dtype=float32),
#  array([[[ 0.9760707 ,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081]],
#
#         [[ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.9760707 ,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081]],
#
#         [[ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.9760707 ,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#            0.12362335,  0.63751081]],
#
#         ...,
#
#         [[ 0.98942659,  0.15606867, -0.15928416, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.15606867, -0.15926271, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.15604877, -0.15928416, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.15604877, -0.15926271, ...,  0.22159857,
#            0.12334802,  0.63761258]],
#
#         [[ 0.98942659,  0.15606867, -0.15926271, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.15604877, -0.15928416, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.15604877, -0.15926271, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.15606867, -0.15926271, ...,  0.22159857,
#            0.12334802,  0.63761258]],
#
#         [[ 0.98942659,  0.15604877, -0.15928416, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.15604877, -0.15926271, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.15606867, -0.15926271, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98944885,  0.15606867, -0.15928416, ...,  0.22159857,
#            0.12334802,  0.63761258]]]),
#  array([[ 0.9760707 ,  0.169684  , -0.1053495 , ...,  0.22157406,
#           0.12362335,  0.63751081],
#         [ 0.97609296,  0.169684  , -0.1053495 , ...,  0.22157406,
#           0.12362335,  0.63751081],
#         [ 0.9760707 ,  0.169684  , -0.1053495 , ...,  0.22157406,
#           0.12362335,  0.63751081],
#         ...,
#         [ 0.98942659,  0.15606867, -0.15926271, ...,  0.22159857,
#           0.12334802,  0.63761258],
#         [ 0.98944885,  0.15606867, -0.15928416, ...,  0.22159857,
#           0.12334802,  0.63761258],
#         [ 0.98942659,  0.15604877, -0.15928416, ...,  0.22159857,
#           0.12334802,  0.63761258]]))

# %%
# 对替换后的inv_yhat预测数据进行逆缩放
inv_yhat = scaler.inverse_transform(yhat)
inv_yhat, inv_yhat.shape
# Out:
# (array([[ 9.6360952e-01, -1.2688318e-01,  1.7603201e-01, ...,
#          -5.1700082e-02, -2.4296702e-03, -1.2000147e-02],
#         [ 9.6361166e-01, -1.2688376e-01,  1.7603400e-01, ...,
#          -5.1688045e-02, -2.4290208e-03, -1.1998683e-02],
#         [ 9.6360606e-01, -1.2688230e-01,  1.7602843e-01, ...,
#          -5.1719595e-02, -2.4306066e-03, -1.2002666e-02],
#         ...,
#         [ 9.7859800e-01, -1.2791809e-01,  1.6115494e-01, ...,
#           1.4344350e-02, -6.5496628e-04,  6.2849196e-03],
#         [ 9.7859800e-01, -1.2791775e-01,  1.6115497e-01, ...,
#           1.4345689e-02, -6.5513945e-04,  6.2853880e-03],
#         [ 9.7859842e-01, -1.2791707e-01,  1.6115549e-01, ...,
#           1.4347998e-02, -6.5533968e-04,  6.2854760e-03]], dtype=float32),
#  (1710, 14))

# %%
# 对重构后数据进行逆缩放
inv_y = scaler.inverse_transform(test_y)
inv_y, inv_y.shape
# Out:
# (array([[ 9.7213e-01, -1.2104e-01,  1.8551e-01, ...,  5.0000e-05,
#          -1.0000e-04,  0.0000e+00],
#         [ 9.7214e-01, -1.2104e-01,  1.8551e-01, ...,  5.0000e-05,
#          -1.0000e-04,  0.0000e+00],
#         [ 9.7213e-01, -1.2104e-01,  1.8551e-01, ...,  5.0000e-05,
#          -1.0000e-04,  0.0000e+00],
#         ...,
#         [ 9.7813e-01, -1.2788e-01,  1.6037e-01, ...,  1.0000e-04,
#          -1.5000e-04,  5.0000e-05],
#         [ 9.7814e-01, -1.2788e-01,  1.6036e-01, ...,  1.0000e-04,
#          -1.5000e-04,  5.0000e-05],
#         [ 9.7813e-01, -1.2789e-01,  1.6036e-01, ...,  1.0000e-04,
#          -1.5000e-04,  5.0000e-05]]),
#  (1710, 14))

# %%
# 计算预测列和真实列的误差RMSE值
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print("Test RMSE: %.3f" % rmse)

# 真实值和预测值之间的平均绝对误差
mae = mean_absolute_error(inv_y, inv_yhat)
print("Test MAE: %.3f" % mae)
# Out:
# Test RMSE: 0.597
# Test MAE: 0.155

# %%
plt.figure(figsize=(12,16), dpi=100)
for i in range(0, 12, 4):
    plt.subplot(4, 4, i+1)
    plt.plot(inv_y[:, i])
    plt.plot(inv_yhat[:, i])
    plt.subplot(4, 4, i+2)
    plt.plot(inv_y[:, i+1])
    plt.plot(inv_yhat[:, i+1])
    plt.subplot(4, 4, i+3)
    plt.plot(inv_y[:, i+2])
    plt.plot(inv_yhat[:, i+2])
    plt.subplot(4, 4, i+4)
    plt.plot(inv_y[:, i+3])
    plt.plot(inv_yhat[:, i+3])
plt.subplot(4, 4, 13)
plt.plot(inv_y[:, 12])
plt.plot(inv_yhat[:, 12])
plt.subplot(4, 4, 14)
plt.plot(inv_y[:, 13])
plt.plot(inv_yhat[:, 13])
plt.show()

# %%
# 将所有数据缩放到[-1, 1]之间
one_scaled_values = scaler.transform(x2)
one_scaled_values, one_scaled_values.shape
# Out:
# (array([[ 0.9760707 ,  0.16970391, -0.10532806, ...,  0.22157406,
#           0.12362335,  0.63751081],
#         [ 0.9760707 ,  0.16970391, -0.10532806, ...,  0.22157406,
#           0.12362335,  0.63751081],
#         [ 0.9760707 ,  0.169684  , -0.10532806, ...,  0.22157406,
#           0.12362335,  0.63751081],
#         ...,
#         [ 0.98942659,  0.1561682 , -0.15915549, ...,  0.22159857,
#           0.12334802,  0.63761258],
#         [ 0.98942659,  0.1561483 , -0.15915549, ...,  0.22159857,
#           0.12334802,  0.63761258],
#         [ 0.98942659,  0.1561682 , -0.15915549, ...,  0.22159857,
#           0.12334802,  0.63761258]]),
#  (2430, 14))

# %%
# 将数据转换为监督学习型数据
one_supervised = timeseries_to_supervised(one_scaled_values, 4, 1)
one_supervised_values = one_supervised.values
one_supervised_values, one_supervised_values.shape
# Out:
# (array([[ 0.9760707 ,  0.16970391, -0.10532806, ...,  0.22157406,
#           0.12362335,  0.63751081],
#         [ 0.9760707 ,  0.16970391, -0.10532806, ...,  0.22157406,
#           0.12362335,  0.63751081],
#         [ 0.9760707 ,  0.169684  , -0.10532806, ...,  0.22157406,
#           0.12362335,  0.63751081],
#         ...,
#         [ 0.98942659,  0.1561682 , -0.15915549, ...,  0.22159857,
#           0.12334802,  0.63761258],
#         [ 0.98942659,  0.1561483 , -0.15915549, ...,  0.22159857,
#           0.12334802,  0.63761258],
#         [ 0.98942659,  0.1561483 , -0.15915549, ...,  0.22159857,
#           0.12334802,  0.63761258]]),
#  (2426, 70))

# %%
# 目标值和特征值
one_X, one_y = one_supervised_values[:, :4*n_features], one_supervised_values[:, 4*n_features:]
one_X.shape, one_y.shape
# Out:
# ((2426, 56), (2426, 14))

# %%
# 将输入数据转换成3维张量[samples, timesteps, features], [1次批量n条数据， 每条数据4个步长，14个特征值]
one_X = one_X.reshape((one_X.shape[0], 4, n_features))
one_X.shape, one_y.shape
# Out:
# ((2426, 4, 14), (2426, 14))

# %%
# 使用训练好的模型网络进行预测
one_yhat = load_model.predict(one_X, batch_size=4)
one_yhat = one_yhat.reshape(one_yhat.shape[0], one_yhat.shape[1])
one_yhat, one_X, one_y
# Out:
# (array([[ 0.9571061 ,  0.15805097, -0.12567198, ...,  0.19620366,
#           0.11079375,  0.61308604],
#         [ 0.9571016 ,  0.158053  , -0.1256778 , ...,  0.19620053,
#           0.11079194,  0.61308396],
#         [ 0.957101  ,  0.158053  , -0.12567818, ...,  0.19619943,
#           0.11079125,  0.6130833 ],
#         ...,
#         [ 0.99047303,  0.1559927 , -0.15757143, ...,  0.22860233,
#           0.12058683,  0.6502672 ],
#         [ 0.9904742 ,  0.15599422, -0.1575711 , ...,  0.22860374,
#           0.12058495,  0.65026826],
#         [ 0.990474  ,  0.15599383, -0.15757105, ...,  0.22860245,
#           0.12058546,  0.65026855]], dtype=float32),
#  array([[[ 0.9760707 ,  0.16970391, -0.10532806, ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.9760707 ,  0.16970391, -0.10532806, ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.9760707 ,  0.169684  , -0.10532806, ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.9760707 ,  0.16970391, -0.10532806, ...,  0.22157406,
#            0.12362335,  0.63751081]],
#
#         [[ 0.9760707 ,  0.16970391, -0.10532806, ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.9760707 ,  0.169684  , -0.10532806, ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.9760707 ,  0.16970391, -0.10532806, ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.9760707 ,  0.16970391, -0.10532806, ...,  0.22157406,
#            0.12362335,  0.63751081]],
#
#         [[ 0.9760707 ,  0.169684  , -0.10532806, ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.9760707 ,  0.16970391, -0.10532806, ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.9760707 ,  0.16970391, -0.10532806, ...,  0.22157406,
#            0.12362335,  0.63751081],
#          [ 0.9760707 ,  0.16970391, -0.10532806, ...,  0.22157406,
#            0.12362335,  0.63751081]],
#
#         ...,
#
#         [[ 0.98942659,  0.1561682 , -0.15915549, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.1561483 , -0.15915549, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.1561483 , -0.15915549, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.1561483 , -0.15913404, ...,  0.22159857,
#            0.12334802,  0.63761258]],
#
#         [[ 0.98942659,  0.1561483 , -0.15915549, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.1561483 , -0.15915549, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.1561483 , -0.15913404, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.1561682 , -0.15915549, ...,  0.22159857,
#            0.12334802,  0.63761258]],
#
#         [[ 0.98942659,  0.1561483 , -0.15915549, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.1561483 , -0.15913404, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.1561682 , -0.15915549, ...,  0.22159857,
#            0.12334802,  0.63761258],
#          [ 0.98942659,  0.1561483 , -0.15915549, ...,  0.22159857,
#            0.12334802,  0.63761258]]]),
#  array([[ 0.9760707 ,  0.16970391, -0.10532806, ...,  0.22157406,
#           0.12362335,  0.63751081],
#         [ 0.9760707 ,  0.16970391, -0.10532806, ...,  0.22157406,
#           0.12362335,  0.63751081],
#         [ 0.9760707 ,  0.16970391, -0.10532806, ...,  0.22157406,
#           0.12362335,  0.63751081],
#         ...,
#         [ 0.98942659,  0.1561682 , -0.15915549, ...,  0.22159857,
#           0.12334802,  0.63761258],
#         [ 0.98942659,  0.1561483 , -0.15915549, ...,  0.22159857,
#           0.12334802,  0.63761258],
#         [ 0.98942659,  0.1561682 , -0.15915549, ...,  0.22159857,
#           0.12334802,  0.63761258]]))

# %%
# 对替换后的inv_yhat预测数据进行逆缩放
one_inv_yhat = scaler.inverse_transform(one_yhat)
one_inv_yhat, one_inv_yhat.shape
# Out:
# (array([[ 9.6361035e-01, -1.2688415e-01,  1.7603353e-01, ...,
#          -5.1704336e-02, -2.4298541e-03, -1.2000498e-02],
#         [ 9.6360832e-01, -1.2688313e-01,  1.7603081e-01, ...,
#          -5.1710721e-02, -2.4301843e-03, -1.2001524e-02],
#         [ 9.6360803e-01, -1.2688313e-01,  1.7603064e-01, ...,
#          -5.1712971e-02, -2.4303088e-03, -1.2001846e-02],
#         ...,
#         [ 9.7860014e-01, -1.2791817e-01,  1.6115865e-01, ...,
#           1.4387333e-02, -6.5143214e-04,  6.2675239e-03],
#         [ 9.7860068e-01, -1.2791741e-01,  1.6115880e-01, ...,
#           1.4390190e-02, -6.5177312e-04,  6.2680510e-03],
#         [ 9.7860056e-01, -1.2791760e-01,  1.6115883e-01, ...,
#           1.4387576e-02, -6.5168110e-04,  6.2681977e-03]], dtype=float32),
#  (2426, 14))

# %%
# 对重构后数据进行逆缩放
one_inv_y = scaler.inverse_transform(one_y)
one_inv_y
# Out:
# array([[ 9.7213e-01, -1.2103e-01,  1.8552e-01, ...,  5.0000e-05,
#         -1.0000e-04,  0.0000e+00],
#        [ 9.7213e-01, -1.2103e-01,  1.8552e-01, ...,  5.0000e-05,
#         -1.0000e-04,  0.0000e+00],
#        [ 9.7213e-01, -1.2103e-01,  1.8552e-01, ...,  5.0000e-05,
#         -1.0000e-04,  0.0000e+00],
#        ...,
#        [ 9.7813e-01, -1.2783e-01,  1.6042e-01, ...,  1.0000e-04,
#         -1.5000e-04,  5.0000e-05],
#        [ 9.7813e-01, -1.2784e-01,  1.6042e-01, ...,  1.0000e-04,
#         -1.5000e-04,  5.0000e-05],
#        [ 9.7813e-01, -1.2783e-01,  1.6042e-01, ...,  1.0000e-04,
#         -1.5000e-04,  5.0000e-05]])

# %%
# 计算预测列和真实列的误差RMSE值
one_rmse = sqrt(mean_squared_error(one_inv_y, one_inv_yhat))
print("Test RMSE: %.3f" % one_rmse)

# 真实值和预测值之间的平均绝对误差
one_mae = mean_absolute_error(one_inv_y, one_inv_yhat)
print("Test MAE: %.3f" % one_mae)
# Out:
# Test RMSE: 1.385
# Test MAE: 0.199

# %%
plt.figure(figsize=(12,16), dpi=100)
for i in range(0, 12, 4):
    plt.subplot(4, 4, i+1)
    plt.plot(one_inv_y[:, i])
    plt.plot(one_inv_yhat[:, i])
    plt.subplot(4, 4, i+2)
    plt.plot(one_inv_y[:, i+1])
    plt.plot(one_inv_yhat[:, i+1])
    plt.subplot(4, 4, i+3)
    plt.plot(one_inv_y[:, i+2])
    plt.plot(one_inv_yhat[:, i+2])
    plt.subplot(4, 4, i+4)
    plt.plot(one_inv_y[:, i+3])
    plt.plot(one_inv_yhat[:, i+3])
plt.subplot(4, 4, 13)
plt.plot(one_inv_y[:, 12])
plt.plot(one_inv_yhat[:, 12])
plt.subplot(4, 4, 14)
plt.plot(one_inv_y[:, 13])
plt.plot(one_inv_yhat[:, 13])
plt.show()

# %%
# Out:
# DatetimeIndex(['2021-06-25 11:54:39', '2021-06-25 11:54:41',
#                '2021-06-25 11:54:43', '2021-06-25 11:54:45',
#                '2021-06-25 11:54:47', '2021-06-25 11:54:49',
#                '2021-06-25 11:54:51', '2021-06-25 11:54:53',
#                '2021-06-25 11:54:55', '2021-06-25 11:54:57',
#                ...
#                '2021-07-01 16:04:26', '2021-07-01 16:04:28',
#                '2021-07-01 16:04:30', '2021-07-01 16:04:32',
#                '2021-07-02 05:51:46', '2021-07-02 05:51:48',
#                '2021-07-02 05:51:50', '2021-07-02 05:51:52',
#                '2021-07-02 05:51:54', '2021-07-02 05:51:56'],
#               dtype='datetime64[ns]', name='DateTime', length=8152, freq=None)
